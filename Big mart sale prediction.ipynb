# %% [markdown]
# ## MÔ TẢ DỮ LIỆU

# %%
from IPython.display import display, Image
display(Image("D:\Project\data\BigMartSales Prediction\Description.png"))

# %% [markdown]
# ## XÁC ĐỊNH CÁC BƯỚC THỰC HIỆN
#
# ### 1, Tìm hiểu dữ liệu
# - Feature
# - Target
# - phân loại hoặc dự đoán (classification or regression)
# #### Kiểm tra:
# - Giá trị bị thiếu (missing values)
# - Giá trị ngoại lai, nhiễu (outlier(noise) values)
# - Không nhất quán (inconsistent)
# - Mất Cân bằng (imbalanced)
# - skewness
#
# ### 2, Tìm hiểu Feature
# - Phân tích khám phá dữ liệu (exploratory data analysis)
#
# ### 3, Xử lý dữ liệu
#
# ### 4, Phân vùng dữ liệu
#
# ### 5, Xây dựng mô hình
#
# ### 6, Đánh giá mô hình
#
# ### 7, Lưu mô hình
#
# ### 8, Kết luận
# --------------------------------------------------------------------------

# %% [markdown]
# ### 1, tìm hiểu dữ liệu

# %%
# khai báo thêm các thư viện cần thiết
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# display(train.describe())
# train.describe(include = 'O')

# %%
import pandas as pd

train = pd.read_csv(r"D:\Project\data\BigMartSales Prediction\Train.csv")
test = pd.read_csv(r"D:\Project\data\BigMartSales Prediction\Test.csv")

display(train.head())
display(test.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
train.Item_Outlet_Sales.value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
print('số dòng và số trường của bộ train lần lượt là',train.shape)
print('số dòng và số trường của bộ test lần lượt là',test.shape)
# Out:
# số dòng và số trường của bộ train lần lượt là (8523, 12)
# số dòng và số trường của bộ test lần lượt là (5681, 11)

# %% [markdown]
# #### ==> mục tiêu của project này là dự đoán trường 'Item_Outlet_Sales' có 3493 giá trị khác nhau và kiểu dữ liệu là int64. nên chúng ta sẽ chọn kiểu mô hình là dự đoán (regression)

# %%
# Chúng ta nên kết hợp bộ train và test để có thể phân tích và dự đoán tốt hơn


# tạo thêm một cột 'Item_Outlet_Sales' cho cột test gán tất cả giá trị bằng 0
test['Item_Outlet_Sales'] = 0

# chúng ta sẽ tạo thêm cho bộ train và test một cột 'source' để có thể phân biệt dữ liệu của 2 bộ này
train['source'] = 'train'
test['source'] = 'test'

# gộp 2 bộ lại với nhau
df = pd.concat([train, test], sort = False, ignore_index = True)

# sau đó tách ra để kiểm tra
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998         NaN               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales source
# 0      Supermarket Type1          3735.1380  train
# 1      Supermarket Type2           443.4228  train
# 2      Supermarket Type1          2097.2700  train
# 3          Grocery Store           732.3800  train
# 4      Supermarket Type1           994.7052  train
# ...                  ...                ...    ...
# 14199  Supermarket Type1             0.0000   test
# 14200  Supermarket Type2             0.0000   test
# 14201  Supermarket Type1             0.0000   test
# 14202  Supermarket Type1             0.0000   test
# 14203  Supermarket Type1             0.0000   test
#
# [14204 rows x 13 columns]

# %%
# kiểm tra dữ liệu bị thiếu

display(round((df.isnull().sum()/df.shape[0] * 100), 2))
# Out:
# Item_Identifier               0.00
# Item_Weight                  17.17
# Item_Fat_Content              0.00
# Item_Visibility               0.00
# Item_Type                     0.00
# Item_MRP                      0.00
# Outlet_Identifier             0.00
# Outlet_Establishment_Year     0.00
# Outlet_Size                  28.27
# Outlet_Location_Type          0.00
# Outlet_Type                   0.00
# Item_Outlet_Sales             0.00
# source                        0.00
# dtype: float64

# %%
for i in list(df.columns):
    print(df[i].value_counts(), '\n')
# Out:
# FDU15    10
# FDS25    10
# FDA38    10
# FDW03    10
# FDJ10    10
#          ..
# FDR51     7
# FDM52     7
# DRN11     7
# FDH58     7
# NCW54     7
# Name: Item_Identifier, Length: 1559, dtype: int64
#
# 17.600    135
# 12.150    127
# 10.500    123
# 13.650    115
# 11.800    113
#          ...
# 7.640       7
# 5.905       7
# 7.850       6
# 4.615       6
# 9.035       6
# Name: Item_Weight, Length: 415, dtype: int64
#
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
#
# 0.000000    879
# 0.076841      3
# 0.077011      3
# 0.077169      3
# 0.076792      3
#            ...
# 0.162572      1
# 0.014826      1
# 0.058034      1
# 0.043786      1
# 0.104720      1
# Name: Item_Visibility, Length: 13006, dtype: int64
#
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
#
# 172.0422    8
# 188.1872    7
# 127.1020    7
# 113.2834    7
# 196.5768    7
#            ..
# 113.7834    1
# 91.4146     1
# 84.2250     1
# 209.0638    1
# 188.0530    1
# Name: Item_MRP, Length: 8052, dtype: int64
#
# OUT027    1559
# OUT013    1553
# OUT049    1550
# OUT046    1550
# OUT035    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64
#
# 1985    2439
# 1987    1553
# 1999    1550
# 1997    1550
# 2004    1550
# 2002    1548
# 2009    1546
# 2007    1543
# 1998     925
# Name: Outlet_Establishment_Year, dtype: int64
#
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64
#
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
#
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64
#
# 0.0000       5681
# 958.7520       17
# 1342.2528      16
# 703.0848       15
# 1845.5976      15
#              ...
# 7152.0236       1
# 9779.9362       1
# 1451.4440       1
# 3723.8194       1
# 3022.7320       1
# Name: Item_Outlet_Sales, Length: 3494, dtype: int64
#
# train    8523
# test     5681
# Name: source, dtype: int64

# %% [markdown]
# #### ==> nhìn vào thống kê trên chúng ta có thể thấy: dữ liệu bị thiếu ở cột 'Item_Weight'(17,17%) và 'Outlet_Size'(28,27%)
#
#
# #### ==> có một số giá trị không hợp lý như cột 'Item_Víibility' với giá trị 0 (5681/14204)

# %%
# kiểm tra giá trị ngoại lai, nhiễu

#tạo một dataframe mới lọc những giá của Item_Visibility lớn hơn 0
df1 = df[df.Item_Visibility > 0]

stats = df1.describe()
for i in stats.columns:
    meanV, stdV = stats.loc['mean', i], stats.loc['std', i]
    minV, maxV = stats.loc['min', i], stats.loc['max', i]
    q1, q2, q3 = stats.loc['25%', i], stats.loc['50%', i], stats.loc['75%', i]
    iqr = q3 - q1
    ConfRange1 = [round(meanV - 3 * stdV,2), round(meanV + 3 * stdV, 2)]
    ConfRange2 = [round(q1 - 1.5 * iqr,2), round(q3 + 1.5 * iqr, 2)]
    print(f'{i}: \n\t min là {minV}, max là {maxV} \n\t confident range 1 là {ConfRange1} và range 2 là {ConfRange2}')
# Out:
# Item_Weight:
# 	 min là 4.555, max là 21.35
# 	 confident range 1 là [-1.15, 26.75] và range 2 là [-3.35, 28.81]
# Item_Visibility:
# 	 min là 0.003574698, max là 0.328390948
# 	 confident range 1 là [-0.08, 0.22] và range 2 là [-0.07, 0.2]
# Item_MRP:
# 	 min là 31.29, max là 266.8884
# 	 confident range 1 là [-44.93, 327.14] và range 2 là [-43.43, 323.43]
# Outlet_Establishment_Year:
# 	 min là 1985.0, max là 2009.0
# 	 confident range 1 là [1972.7, 2022.96] và range 2 là [1961.5, 2029.5]
# Item_Outlet_Sales:
# 	 min là 0.0, max là 13086.9648
# 	 confident range 1 là [-3785.48, 6400.42] và range 2 là [-3245.77, 5409.62]

# %% [markdown]
# #### ==> cột Item_Visibility có giá trị max lớn hơn range

# %%
# kiểm tra phân phối của dữ liệu

df.skew()
# Out:
# Item_Weight                  0.101309
# Item_Visibility              1.195175
# Item_MRP                     0.130728
# Outlet_Establishment_Year   -0.396465
# Item_Outlet_Sales            1.544684
# dtype: float64

# %% [markdown]
# #### ==> lệch ít, toàn bộ đều nhỏ hơn 4

# %%
# dữ liệu không nhất quán


# tách những cột mang giá trị phân loại
categorical = [i for i in df.columns if df[i].nunique()< 20 and i != 'source']
print(categorical)
for i in df[categorical]:
    print('\n', df[i].value_counts())
# Out:
# ['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
#
#  Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
#
#  Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
#
#  OUT027    1559
# OUT013    1553
# OUT049    1550
# OUT046    1550
# OUT035    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64
#
#  1985    2439
# 1987    1553
# 1999    1550
# 1997    1550
# 2004    1550
# 2002    1548
# 2009    1546
# 2007    1543
# 1998     925
# Name: Outlet_Establishment_Year, dtype: int64
#
#  Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64
#
#  Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
#
#  Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# ####  ==> Low Fat & LF & low fat có nghĩa tương tự
# ####  ==> Regular & reg có nghĩa tương tự

# %% [markdown]
# ### 2, tìm hiểu feature

# %% [markdown]
# #### Trực quan hóa, phân tích đơn biến, hai biến, đa biến

# %%
# tách thêm những cột mang giá trị định lượng
numeric = set(df.columns) - set(categorical) - set(['Item_Identifier', 'source', 'Item_Outlet_Sales'])
numeric
# Out:
# {'Item_MRP', 'Item_Visibility', 'Item_Weight'}

# %%
# phân tích đơn biến
# - categorical features nên sử dụng những loại biểu đồ như: bar chart (so sánh), pie (tỉ lệ phần trăm) 
# - numeric features nên sử dụng những loại biểu đồ như: histogram (hình dạng phân phối), boxplot (range and outlier)

for i in df[categorical]:
    print('\t\t', i, 'feature','\n')
    print(df[i].value_counts())
    
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    df[i].value_counts().plot.pie(autopct='%1.1f%%')
    
    plt.subplot(1,2,2)
    sns.countplot(x = df[i])
    plt.xticks(rotation = 50)
    
    plt.show()
    print('-----------------------------------------------------------------------------------------------------------------')
# Out:
# 		 Item_Fat_Content feature
#
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
# -----------------------------------------------------------------------------------------------------------------
# 		 Item_Type feature
#
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
# -----------------------------------------------------------------------------------------------------------------
# 		 Outlet_Identifier feature
#
# OUT027    1559
# OUT013    1553
# OUT049    1550
# OUT046    1550
# OUT035    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64
# -----------------------------------------------------------------------------------------------------------------
# 		 Outlet_Establishment_Year feature
#
# 1985    2439
# 1987    1553
# 1999    1550
# 1997    1550
# 2004    1550
# 2002    1548
# 2009    1546
# 2007    1543
# 1998     925
# Name: Outlet_Establishment_Year, dtype: int64
# -----------------------------------------------------------------------------------------------------------------
# 		 Outlet_Size feature
#
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64
# -----------------------------------------------------------------------------------------------------------------
# 		 Outlet_Location_Type feature
#
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
# -----------------------------------------------------------------------------------------------------------------
# 		 Outlet_Type feature
#
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ==> cần gom các giá trị của 'low fat' lại. tương tự với 'regular'. sản phẩm 'low fat' nhiều hơn sản phẩm 'regular'.
#
# ==> có 10 'outlets' tất cả gần như cân đối trừ 'OUT010' và 'OUT019'
#
# ==> 'Fruits and Vegetables' và 'Snack Foods' là 2 loại chiếm hầu hết, ít nhất là 'Seafood'
#
# ==> năm 1985 mở nhiều cửa hàng nhất, các năm còn lại gần nhưu cân đối. ít nhất là năm 1998
#
# ==> có rất ít của hàng có quy mô lớn, đa phần là tầm trung
#
# ==> các của hàng được mở ở thành phố loại 2 nhiều nhất chiếm 39%
#
# ==> 65% của 'outlets' là siêu thị loại 1

# %%
for i in numeric:
    print('\t\t', i, 'feature','\n')
    f, (ax_box, ax_hist) = plt.subplots(2, sharex = True, gridspec_kw = {'height_ratios': (.15, .85)})
    f.set_figheight(4)
    f.set_figwidth(15)
    sns.boxplot(x = df[i], ax = ax_box)
    sns.histplot(data = df, x = i, ax = ax_hist)
    plt.show()
    print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# 		 Item_MRP feature
# ---------------------------------------------------------------------------------------------------------------------
# 		 Item_Visibility feature
# ---------------------------------------------------------------------------------------------------------------------
# 		 Item_Weight feature
# ---------------------------------------------------------------------------------------------------------------------

# %%
for i in numeric:
    print('\t\t', i, 'feature','\n')
    sns.distplot(df[i])
    plt.show()
    print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# 		 Item_MRP feature
# ---------------------------------------------------------------------------------------------------------------------
# 		 Item_Visibility feature
# ---------------------------------------------------------------------------------------------------------------------
# 		 Item_Weight feature
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ==> 'Item_Visibility' có thể có giá trị ngoại lai và phân phối đang lệch về bên phải

# %% [markdown]
# #### phân tích 2 biến
# - categorical vs cateforical: stripplot
# - categorical vs numeric: stripplot
# - numeric vs numeric: scatter

# %%
sns.stripplot(x = df['Outlet_Location_Type'],y = df['Outlet_Type'])
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='Outlet_Type'>

# %% [markdown]
# ==> thành phố loại 3 có đủ các dạng cửa hàng, thành phố loại 1 chỉ có 'Grocery Store' và 'Supermarket Type1' còn thành phố loại 2 chỉ phát triển 'Supermarket Type1'

# %%
sns.stripplot(x = df['Outlet_Size'], y = df['Outlet_Type'])
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Outlet_Type'>

# %% [markdown]
# ==> Siêu thị loại 1 có đủ quy mô trong khi 'Grocery Store' chỉ có quy mô nhỏ và Siêu thị loại 2, Siêu thị loại 3 chỉ có quy mô vừa.

# %%
sns.stripplot(x = df['Outlet_Establishment_Year'], y = df['Outlet_Type'])
plt.show()

# %% [markdown]
# ==> 'supermarket type2' được xây dựng muộn hơn nhiều trong khi các 'grocery store' và siêu thị là loại hình cửa hàng lâu đời nhất.

# %%
sns.stripplot(x = df['Outlet_Establishment_Year'], y = df['Outlet_Location_Type'])
# Out:
# <Axes: xlabel='Outlet_Establishment_Year', ylabel='Outlet_Location_Type'>

# %% [markdown]
# ==> Ở các thành phố cấp 1 và cấp 2, các cửa hàng được thành lập vào năm 1985 trong khi cấp 2 có cửa hàng sau năm 2000

# %%
sns.stripplot(x = df['Outlet_Establishment_Year'],y = df['Outlet_Size'])
# Out:
# <Axes: xlabel='Outlet_Establishment_Year', ylabel='Outlet_Size'>

# %% [markdown]
# ==> Sau năm 1990 không có cửa hàng quy mô lớn nào được thành lập

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x = df['Outlet_Identifier'],y = df['Outlet_Type'])
# Out:
# <Axes: xlabel='Outlet_Identifier', ylabel='Outlet_Type'>

# %% [markdown]
# ==> Chỉ có một mã định danh 'OUT' cho siêu thị 2 và 3 trong khi hầu hết các mã định danh cửa hàng đều thuộc về siêu thị 1

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x = df['Outlet_Identifier'],y = df['Outlet_Location_Type'])
# Out:
# <Axes: xlabel='Outlet_Identifier', ylabel='Outlet_Location_Type'>

# %% [markdown]
# ==> Cấp 3 có nhiều loại cửa hàng khác nhau nhất nhưng chúng gần như cân bằng.

# %%
sns.stripplot(x = df['Outlet_Size'],y = df['Outlet_Identifier'])
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Outlet_Identifier'>

# %% [markdown]
# ==> Chỉ có 'Outlet13' có kích thước cửa hàng lớn trong khi các cửa hàng vừa và nhỏ đều có 3 cửa hàng

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x = df['Outlet_Identifier'],y = df['Outlet_Establishment_Year'])
# Out:
# <Axes: xlabel='Outlet_Identifier', ylabel='Outlet_Establishment_Year'>

# %% [markdown]
# ==> cửa hàng 27 và 19 là mã nhận dạng cửa hàng lâu đời nhất và cửa hàng 18 là cửa hàng mới nhất

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x = df['Outlet_Identifier'],y = df['Item_Visibility'])
# Out:
# <Axes: xlabel='Outlet_Identifier', ylabel='Item_Visibility'>

# %% [raw]
# ==> Outlet10 và 19 mang lại khả năng trưng bày sản phẩm cao nhất. Các cửa hàng khác cung cấp khả năng trưng bày gần như bằng nhau.

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x = df['Outlet_Type'],y =df['Item_Visibility'])
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Visibility'>

# %% [markdown]
# ==> Sản phẩm được thấy rõ nhất ở các cửa hàng tạp hóa hơn là bất kỳ siêu thị nào khác

# %%
sns.stripplot(x = df['Outlet_Size'],y = df['Item_Visibility'])
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Item_Visibility'>

# %% [markdown]
# ==> Cửa hàng nhỏ nhất cung cấp khả năng hiển thị tốt nhất cho sản phẩm

# %%
sns.countplot(x = df['Outlet_Location_Type'],hue=df['Outlet_Type'])
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='count'>

# %% [markdown]
# ==> Các thành phố cấp 2 có số lượng cao nhất. của siêu thị 2 và không có loại cửa hàng nào khác trong khi các thành phố cấp 3 có tất cả các loại cửa hàng với số lượng ít hơn. của mỗi người trong số họ.

# %%
sns.countplot(x = df['Outlet_Size'],hue=df['Outlet_Location_Type'])
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='count'>

# %% [markdown]
# ==> Các thành phố cấp 3 có số lượng cao nhất của cửa hàng quy mô vừa và thành phố loại 1 có số lượng cửa hàng lớn nhất. các cửa hàng có quy mô nhỏ. Các thành phố cấp 3 có ít nhất. của các cửa hàng

# %%
sns.lmplot(x='Item_Weight',y='Item_Outlet_Sales',data=df)

# %% [markdown]
# ==> Không có mối quan hệ nào giữa trọng lượng mặt hàng và doanh số bán hàng tại cửa hàng.

# %%
sns.lmplot(x='Item_Visibility',y='Item_Outlet_Sales',data=df)

# %% [markdown]
# ==> Doanh số bán hàng tại cửa hàng giảm mạnh đối với những mặt hàng dễ thấy nhất

# %%
sns.lmplot(x='Item_MRP',y='Item_Outlet_Sales',data=df)

# %% [markdown]
# ==> Khi giá trị của một mặt hàng tăng lên thì doanh số bán hàng tại cửa hàng cũng tăng lên.

# %% [markdown]
# #### Phân tích đa biến

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x = 'Outlet_Location_Type',y ='Item_Outlet_Sales',hue='Outlet_Type',data=df)
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ==> Các địa điểm cấp 3 có doanh số bán hàng cao nhất. Cũng có thể thấy rằng họ có hầu hết các loại cửa hàng nên doanh số bán hàng cao hơn

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x = 'Outlet_Size',y = 'Item_Outlet_Sales',hue='Outlet_Type',data=df)
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ==> Có thể thấy rằng các cửa hàng cỡ vừa bán được nhiều nhất và cũng có nhiều loại cửa hàng nhất nên doanh số bán hàng càng tăng cao hơn.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x = 'Item_Visibility',y = 'Item_MRP',hue='Item_Outlet_Sales',data=df,palette='rocket_r')
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Item_MRP'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ==> MRP có mối tương quan tích cực mạnh nhất với Doanh số bán hàng, trong khi tính khả thi và thành lập cho thấy mối tương quan tiêu cực một chút. Không có nhiều mối tương quan giữa các tính năng độc lập.

# %% [markdown]
# ### 3, xử lý dữ liệu

# %%
# cột Item_Visibility:
feature = "Item_Visibility"
df[feature].replace(0, np.nan, inplace = True)
display(df[feature].value_counts())
# Out:
# 0.077169    3
# 0.076841    3
# 0.076483    3
# 0.077290    3
# 0.076856    3
#            ..
# 0.162572    1
# 0.014826    1
# 0.058034    1
# 0.043786    1
# 0.104720    1
# Name: Item_Visibility, Length: 13005, dtype: int64

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.018540  0.036236
# Item_Visibility              -0.018540         1.000000 -0.009230
# Item_MRP                      0.036236        -0.009230  1.000000
# Outlet_Establishment_Year     0.000645        -0.091455  0.000141
# Item_Outlet_Sales             0.019447        -0.080968  0.342781
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                 0.000645           0.019447
# Item_Visibility                            -0.091455          -0.080968
# Item_MRP                                    0.000141           0.342781
# Outlet_Establishment_Year                   1.000000          -0.029489
# Item_Outlet_Sales                          -0.029489           1.000000

# %%
import association_metrics as am
corrdf = df[categorical].copy()
corrdf = corrdf.apply(
        lambda x: x.astype("category") if x.dtype == "O" else x)
cramersv = am.CramersV(corrdf) 
categoric_corr_matrix = cramersv.fit()
display(categoric_corr_matrix)
# Out:
#                       Item_Fat_Content  Item_Type  Outlet_Identifier  \
# Item_Fat_Content              1.000000   0.215021           0.024022
# Item_Type                     0.215021   1.000000           0.008476
# Outlet_Identifier             0.024022   0.008476           1.000000
# Outlet_Size                   0.015573   0.007095           1.000000
# Outlet_Location_Type          0.008796   0.006881           1.000000
# Outlet_Type                   0.015832   0.011276           1.000000
#
#                       Outlet_Size  Outlet_Location_Type  Outlet_Type
# Item_Fat_Content         0.015573              0.008796     0.015832
# Item_Type                0.007095              0.006881     0.011276
# Outlet_Identifier        1.000000              1.000000     1.000000
# Outlet_Size              1.000000              0.578765     0.552700
# Outlet_Location_Type     0.578765              1.000000     0.526540
# Outlet_Type              0.552700              0.526540     1.000000

# %%
table = df.pivot_table(values = feature, index = "Item_Type", columns = "Outlet_Type", aggfunc = "mean")
table
# Out:
# Outlet_Type            Grocery Store  Supermarket Type1  Supermarket Type2  \
# Item_Type
# Baking Goods                0.116306           0.066692           0.068206
# Breads                      0.111612           0.067579           0.067976
# Breakfast                   0.126056           0.079993           0.083079
# Canned                      0.112484           0.066167           0.064655
# Dairy                       0.120742           0.069299           0.069000
# Frozen Foods                0.115895           0.065449           0.064184
# Fruits and Vegetables       0.114820           0.067123           0.067503
# Hard Drinks                 0.109913           0.064873           0.063611
# Health and Hygiene          0.098924           0.055021           0.053081
# Household                   0.099288           0.057774           0.057858
# Meat                        0.095960           0.058676           0.058574
# Others                      0.096714           0.055688           0.056357
# Seafood                     0.122593           0.067158           0.071047
# Snack Foods                 0.114660           0.065578           0.065584
# Soft Drinks                 0.108376           0.064303           0.064451
# Starchy Foods               0.117891           0.066730           0.068340
#
# Outlet_Type            Supermarket Type3
# Item_Type
# Baking Goods                    0.066524
# Breads                          0.066038
# Breakfast                       0.078609
# Canned                          0.067549
# Dairy                           0.069213
# Frozen Foods                    0.064816
# Fruits and Vegetables           0.066758
# Hard Drinks                     0.065297
# Health and Hygiene              0.054924
# Household                       0.057625
# Meat                            0.058451
# Others                          0.055413
# Seafood                         0.075858
# Snack Foods                     0.065126
# Soft Drinks                     0.065485
# Starchy Foods                   0.067608

# %%
Replacement_IndexSeries = df[df[feature].isnull()].apply(lambda rows: table.loc[rows["Item_Type"], rows["Outlet_Type"]], axis=1)
df[feature].fillna(Replacement_IndexSeries, inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# source                          0
# dtype: int64

# %% [markdown]
# ==> chúng ta sẽ thay giá trị bị thiếu của cột Item_Visibility bằng mean

# %%
# cột 'Item_Weight'

feature = "Item_Weight"
wt_table = df.pivot_table(values='Item_Weight', index='Item_Identifier', aggfunc= 'mean')
wt_table
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1559 rows x 1 columns]

# %%
Replacement_IndexSeries = df[df[feature].isnull()].apply(lambda rows: wt_table.loc[rows["Item_Identifier"], feature], axis=1)
df[feature].fillna(Replacement_IndexSeries, inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# source                          0
# dtype: int64

# %%
# cột Outlet_Size

feature = "Outlet_Size"
print("NaN \t", df[feature].isnull().sum())
df[feature].value_counts()
# Out:
# NaN 	 4016
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
df[df["Outlet_Size"].isnull()][["Outlet_Identifier"]]
# Out:
#       Outlet_Identifier
# 3                OUT010
# 8                OUT045
# 9                OUT017
# 25               OUT017
# 28               OUT010
# ...                 ...
# 14191            OUT010
# 14193            OUT017
# 14201            OUT045
# 14202            OUT017
# 14203            OUT045
#
# [4016 rows x 1 columns]

# %%
df['Outlet_Size'].replace(np.NaN,'Unknown',inplace=True)

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium     4655
# Unknown    4016
# Small      3980
# High       1553
# Name: Outlet_Size, dtype: int64

# %%
from scipy.stats import mode

# %%
# Sử dụng pivot_table với np.unique
size_table = df.pivot_table(values='Outlet_Size', index='Outlet_Type', aggfunc=(lambda x: np.unique(x, return_counts=True)[0][np.argmax(np.unique(x, return_counts=True)[1])]))

# Hiển thị bảng tổng hợp
print(size_table)
# Out:
#                   Outlet_Size
# Outlet_Type
# Grocery Store         Unknown
# Supermarket Type1       Small
# Supermarket Type2      Medium
# Supermarket Type3      Medium

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %%
df['Outlet_Size'].replace('Unknown','Small',inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %% [markdown]
# ==> chúng ta điền giá trị bị thiếu là 'small' vì 'Grocery Store' thường là những của hàng loại nhỏ

# %%
# cột Item_Identifier

df['Item_Identifier'].value_counts()
# Out:
# FDU15    10
# FDS25    10
# FDA38    10
# FDW03    10
# FDJ10    10
#          ..
# FDR51     7
# FDM52     7
# DRN11     7
# FDH58     7
# NCW54     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df['Item_Identifier']=df['Item_Identifier'].apply(lambda x: x[:-2])

# %%
df['Item_Identifier'].unique()
# Out:
# array(['FDA', 'DRC', 'FDN', 'FDX', 'NCD', 'FDP', 'FDO', 'FDH', 'FDU',
#        'FDY', 'FDS', 'FDF', 'NCB', 'DRI', 'FDW', 'FDC', 'FDR', 'FDV',
#        'DRJ', 'FDE', 'NCS', 'DRH', 'NCX', 'DRZ', 'FDB', 'FDK', 'FDL',
#        'FDM', 'NCP', 'NCL', 'DRK', 'FDI', 'FDZ', 'NCI', 'FDJ', 'FDG',
#        'NCZ', 'FDQ', 'FDD', 'DRG', 'NCR', 'FDT', 'DRB', 'DRE', 'DRA',
#        'NCF', 'NCH', 'NCO', 'NCN', 'NCC', 'DRD', 'DRF', 'DRL', 'NCM',
#        'NCU', 'DRY', 'NCW', 'DRM', 'NCT', 'NCQ', 'DRP', 'DRQ', 'NCK',
#        'NCY', 'DRN', 'NCA', 'NCE', 'NCJ', 'NCV', 'NCG', 'DRO'],
#       dtype=object)

# %% [markdown]
# ==> Bây giờ cột Item_Identifier trông có ý nghĩa hơn nên chúng ta sẽ giữ nó.

# %%
# cột 'Outlet_Establishment_Year'

df['Outlet_Establishment_Year']=(2024.0 - df['Outlet_Establishment_Year'])
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDA         9.30          Low Fat         0.016047
# 1             DRC         5.92          Regular         0.019278
# 2             FDN        17.50          Low Fat         0.016760
# 3             FDX        19.20          Regular         0.114820
# 4             NCD         8.93          Low Fat         0.057774
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       25.0      Medium               Tier 1
# 1                       15.0      Medium               Tier 3
# 2                       25.0      Medium               Tier 1
# 3                       26.0       Small               Tier 3
# 4                       37.0        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %%
# cột Item_Fat_Content

# hợp nhất 'low fat' và 'regular'
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Item_Fat_Content'].replace('reg','Regular',inplace=True)
df['Item_Fat_Content'].replace(['low fat','LF'],'Low Fat',inplace=True)
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %% [markdown]
# ==> Bây giờ chúng ta chỉ có hai loại trong cột

# %%
# encoding

from sklearn.preprocessing import OrdinalEncoder
e=OrdinalEncoder()

# %%
obj=[feature for feature in df.columns if df[feature].dtypes=='O' and feature!='source']
obj
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for i in obj:
    df[i]=e.fit_transform(df[i].values.reshape(-1,1))

# %%
df.dtypes
# Out:
# Item_Identifier              float64
# Item_Weight                  float64
# Item_Fat_Content             float64
# Item_Visibility              float64
# Item_Type                    float64
# Item_MRP                     float64
# Outlet_Identifier            float64
# Outlet_Establishment_Year    float64
# Outlet_Size                  float64
# Outlet_Location_Type         float64
# Outlet_Type                  float64
# Item_Outlet_Sales            float64
# source                        object
# dtype: object

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             19.0         9.30               0.0         0.016047        4.0
# 1              2.0         5.92               1.0         0.019278       14.0
# 2             32.0        17.50               0.0         0.016760       10.0
# 3             42.0        19.20               1.0         0.114820        6.0
# 4             48.0         8.93               0.0         0.057774        9.0
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                9.0                       25.0          1.0
# 1   48.2692                3.0                       15.0          1.0
# 2  141.6180                9.0                       25.0          1.0
# 3  182.0950                0.0                       26.0          2.0
# 4   53.8614                1.0                       37.0          0.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales source
# 0                   0.0          1.0          3735.1380  train
# 1                   2.0          2.0           443.4228  train
# 2                   0.0          1.0          2097.2700  train
# 3                   2.0          0.0           732.3800  train
# 4                   2.0          1.0           994.7052  train

# %% [markdown]
# ==> Tất cả các cột được chuyển đổi thành kiểu float trừ 'source'.

# %%
# loại bỏ outlier của 'Item_Visibility'
df=df[np.abs(df.Item_Visibility-df.Item_Visibility.mean())<=(3*df.Item_Visibility.std())]

# %%
sns.boxplot(x = df['Item_Visibility'])
# Out:
# <Axes: xlabel='Item_Visibility'>

# %%
df.shape
# Out:
# (14023, 13)

# %%
df = df[df['Item_Visibility'] < 0.15]
df.shape
# Out:
# (13150, 13)

# %%
# xóa skewness của cột visibility
df['Item_Visibility'].skew()
# Out:
# 0.553415572715694

# %%
df['Item_Visibility']=np.sqrt(df['Item_Visibility'])

# %%
df['Item_Visibility'].skew()
# Out:
# 0.014668918020177906

# %%
df.shape
# Out:
# (13150, 13)

# %%
sns.distplot(df['Item_Visibility'])
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Density'>

# %% [markdown]
# ==>  ngoại lai và độ lệch đều bị xóa khỏi cột Item_Visibility

# %% [markdown]
# #### 4, phân vùng dữ liệu

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()

# %%
df.iloc[:,:-2]=m.fit_transform(df.iloc[:,:-2])

# %%
# tách dữ liệu
train = df.loc[df['source']=='train']
test = df.loc[df['source']=='test']

# %%
train.drop('source',axis=1,inplace=True)
test.drop(['source','Item_Outlet_Sales'],axis=1,inplace=True)

# %%
train=train.reset_index(drop=True)
test=test.reset_index(drop=True)

# %%
train
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0            0.271429     0.282525               0.0         0.204246
# 1            0.028571     0.081274               1.0         0.241402
# 2            0.457143     0.770765               0.0         0.212744
# 3            0.600000     0.871986               1.0         0.852120
# 4            0.685714     0.260494               0.0         0.551379
# ...               ...          ...               ...              ...
# 7868         0.342857     0.137541               0.0         0.545062
# 7869         0.528571     0.227746               1.0         0.479295
# 7870         0.771429     0.359929               0.0         0.390211
# 7871         0.457143     0.158083               1.0         0.981059
# 7872         0.085714     0.610003               0.0         0.464304
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0      0.266667  0.927507           1.000000                   0.416667
# 1      0.933333  0.072068           0.333333                   0.000000
# 2      0.666667  0.468288           1.000000                   0.416667
# 3      0.400000  0.640093           0.000000                   0.458333
# 4      0.600000  0.095805           0.111111                   0.916667
# ...         ...       ...                ...                        ...
# 7868   0.866667  0.777729           0.111111                   0.916667
# 7869   0.000000  0.326263           0.777778                   0.291667
# 7870   0.533333  0.228492           0.666667                   0.208333
# 7871   0.866667  0.304939           0.333333                   0.000000
# 7872   0.933333  0.187510           0.888889                   0.500000
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0             0.5                   0.0     0.333333          3735.1380
# 1             0.5                   1.0     0.666667           443.4228
# 2             0.5                   0.0     0.333333          2097.2700
# 3             1.0                   1.0     0.000000           732.3800
# 4             0.0                   1.0     0.333333           994.7052
# ...           ...                   ...          ...                ...
# 7868          0.0                   1.0     0.333333          2778.3834
# 7869          1.0                   0.5     0.333333           549.2850
# 7870          1.0                   0.5     0.333333          1193.1136
# 7871          0.5                   1.0     0.666667          1845.5976
# 7872          1.0                   0.0     0.333333           765.6700
#
# [7873 rows x 12 columns]

# %%
test
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0            0.585714     0.964275               0.0         0.083016
# 1            0.585714     0.222983               1.0         0.416012
# 2            0.828571     0.598095               0.0         0.780983
# 3            0.500000     0.164335               0.0         0.196222
# 4            0.614286     0.538553               1.0         0.869008
# ...               ...          ...               ...              ...
# 5272         0.285714     0.353974               1.0         0.172173
# 5273         0.314286     0.181304               1.0         0.972091
# 5274         0.842857     0.324204               0.0         0.645427
# 5275         0.400000     0.639774               1.0         0.602889
# 5276         0.557143     0.294433               1.0         0.805564
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0      0.866667  0.325012           1.000000                   0.416667
# 1      0.266667  0.237819           0.222222                   0.083333
# 2      0.733333  0.893316           0.000000                   0.458333
# 3      0.866667  0.525233           0.222222                   0.083333
# 4      0.266667  0.861381           0.555556                   1.000000
# ...         ...       ...                ...                        ...
# 5272   0.866667  0.467004           0.888889                   0.500000
# 5273   1.000000  0.585126           0.333333                   0.000000
# 5274   0.533333  0.371199           0.777778                   0.291667
# 5275   0.200000  0.778154           0.222222                   0.083333
# 5276   0.200000  0.205884           0.777778                   0.291667
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0             0.5                   0.0     0.333333
# 1             1.0                   0.5     0.333333
# 2             1.0                   1.0     0.000000
# 3             1.0                   0.5     0.333333
# 4             0.5                   1.0     1.000000
# ...           ...                   ...          ...
# 5272          1.0                   0.0     0.333333
# 5273          0.5                   1.0     0.666667
# 5274          1.0                   0.5     0.333333
# 5275          1.0                   0.5     0.333333
# 5276          1.0                   0.5     0.333333
#
# [5277 rows x 11 columns]

# %%
x=train.iloc[:,:-1]
y=train.iloc[:,-1]

# %% [markdown]
# #### 5, Xây dựng mô hình

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
def randomstate(a,b):
    maxx=0
    for state in range(1,201):
        xtrain,xtest,ytrain,ytest=train_test_split(a,b,test_size=0.2,random_state=state)
        model=LinearRegression()
        model.fit(xtrain,ytrain)
        p=model.predict(xtest)
        r2=r2_score(p,ytest)
        if maxx<r2:
            maxx=r2
            j=state
    return j

# %%
models=[KNeighborsRegressor(),LinearRegression(),Lasso(),Ridge(),ElasticNet(),DecisionTreeRegressor(),
       RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor(),XGBRegressor()]

names=['KNeighborsRegressor','LinearRegression','Lasso','Ridge','ElasticNet','DecisionTreeRegressor',
       'RandomForestRegressor','AdaBoostRegressor','GradientBoostingRegressor','XGBRegressor']

# %%
def performance(p,ytest,s,n):
    print(m)
    print('Mean Absolute Error is',np.round(mean_absolute_error(p,ytest),4))
    print('Mean Squared Error is',np.round(mean_squared_error(p,ytest),4))
    print('Root Mean Squared Error is',np.round(np.sqrt(mean_squared_error(p,ytest)),4))
    print('R2 Score is',np.round(r2_score(p,ytest),4)*100)
    print('Mean of cross validaton Score is',np.round(np.mean(s),4))
    print('--------------------------------------------------------------------------')

# %%
def createmodels(model_list,independent,dependent,n):
    xtrain,xtest,ytrain,ytest=train_test_split(independent,dependent,test_size=0.2,random_state=randomstate(x,y))
    name=[]
    meanabs=[]
    meansqd=[]
    rootmeansqd=[]
    r2=[]
    mcv=[]
    
    # xây dựng mô hình
    for i,model in enumerate(model_list):
        model.fit(xtrain,ytrain)
        p=model.predict(xtest)
        score=cross_val_score(model,independent,dependent,cv=10)
        
        # Tính loss của mô hình và thêm chúng vào danh sách
        name.append(n[i])
        meanabs.append(np.round(mean_absolute_error(p,ytest),4))
        meansqd.append(np.round(mean_squared_error(p,ytest),4))
        rootmeansqd.append(np.round(np.sqrt(mean_squared_error(p,ytest)),4))
        r2.append(np.round(r2_score(p,ytest),4)*100)
        mcv.append(np.round(np.mean(score),4)*100)
    
    # tạo Dataframe
    data=pd.DataFrame()
    data['Model']=name
    data['Mean Absolute Error']=meanabs
    data['Mean Squared Error']=meansqd
    data['Root Mean Squared Error']=rootmeansqd
    data['R2 Score']=r2
    data['Mean of Cross validaton Score']=mcv
    data.set_index('Model',inplace = True)
    return data

# %%
createmodels(models,x,y,names)
# Out:
#                            Mean Absolute Error  Mean Squared Error  \
# Model
# KNeighborsRegressor                   851.1364        1.404707e+06
# LinearRegression                      888.6080        1.378880e+06
# Lasso                                 887.8162        1.378248e+06
# Ridge                                 888.4029        1.378823e+06
# ElasticNet                           1263.6847        2.492568e+06
# DecisionTreeRegressor                1077.2881        2.343593e+06
# RandomForestRegressor                 795.0165        1.244319e+06
# AdaBoostRegressor                    1053.3958        1.681051e+06
# GradientBoostingRegressor             764.2959        1.152342e+06
# XGBRegressor                          827.7623        1.345034e+06
#
#                            Root Mean Squared Error  R2 Score  \
# Model
# KNeighborsRegressor                      1185.2032     20.49
# LinearRegression                         1174.2572      9.46
# Lasso                                    1173.9881      8.54
# Ridge                                    1174.2328      9.05
# ElasticNet                               1578.7870  -8187.42
# DecisionTreeRegressor                    1530.8798     17.96
# RandomForestRegressor                    1115.4904     35.43
# AdaBoostRegressor                        1296.5534    -21.01
# GradientBoostingRegressor                1073.4718     33.33
# XGBRegressor                             1159.7559     31.44
#
#                            Mean of Cross validaton Score
# Model
# KNeighborsRegressor                                49.21
# LinearRegression                                   49.33
# Lasso                                              49.35
# Ridge                                              49.33
# ElasticNet                                         12.24
# DecisionTreeRegressor                              14.54
# RandomForestRegressor                              53.68
# AdaBoostRegressor                                  44.42
# GradientBoostingRegressor                          57.72
# XGBRegressor                                       50.67

# %% [markdown]
# ==> mô hình có chỉ số tốt nhất là GradientBoostingRegressor

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x, y,test_size=0.2,random_state=randomstate(x,y))

# %%
model = GradientBoostingRegressor()
model.fit(xtrain, ytrain)
# Out:
# GradientBoostingRegressor()

# %%
p = model.predict(xtest)

# %% [markdown]
# ### 6, Đánh giá mô hình

# %%
print('Mean Absolute Error is',np.round(mean_absolute_error(p,ytest),4))
print('Mean Squared Error is',np.round(mean_squared_error(p,ytest),4))
print('Root Mean Squared Error is',np.round(np.sqrt(mean_squared_error(p,ytest)),4))
print('R2 Score is',np.round(r2_score(p,ytest),4)*100)
# Out:
# Mean Absolute Error is 764.3597
# Mean Squared Error is 1152472.624
# Root Mean Squared Error is 1073.5328
# R2 Score is 33.33

# %%
plt.scatter(x=ytest,y=p,color='r')
plt.plot(ytest,ytest,color='b')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Gradient Boost Regressor')
# Out:
# Text(0.5, 1.0, 'Gradient Boost Regressor')

# %% [markdown]
# ==> vẫn có giá trị outliers

# %% [markdown]
# ### 7, lưu Mô hình

# %%
import joblib
joblib.dump(model,'Mart_Sales.obj')
# Out:
# ['Mart_Sales.obj']

# %%
predictions=model.predict(test)

# %%
predictions=pd.DataFrame(predictions)

# %%
predictions.to_csv('test_predictions.csv')

# %%
predictions
# Out:
#                 0
# 0     1450.836662
# 1     1437.128130
# 2      614.356891
# 3     2562.900273
# 4     5899.173428
# ...           ...
# 5272  2177.039764
# 5273  2708.631381
# 5274  1825.046011
# 5275  3642.384390
# 5276  1239.583157
#
# [5277 rows x 1 columns]
